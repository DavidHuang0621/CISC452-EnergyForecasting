# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
# Load preprocessed data
df = pd.read_csv('../Data/preprocessed.csv', index_col=0)
df.time = pd.to_datetime(df.time)
df.head()
# Out:
#                  time       use       gen  Dishwasher  Furnace 1  Furnace 2  \
# 0 2016-01-01 05:00:00  0.932833  0.003483    0.000033   0.020700   0.061917
# 1 2016-01-01 05:01:00  0.934333  0.003467    0.000000   0.020717   0.063817
# 2 2016-01-01 05:02:00  0.931817  0.003467    0.000017   0.020700   0.062317
# 3 2016-01-01 05:03:00  1.022050  0.003483    0.000017   0.106900   0.068517
# 4 2016-01-01 05:04:00  1.139400  0.003467    0.000133   0.236933   0.063983
#
#    Home office    Fridge  Wine cellar  Garage door  ...  windBearing  \
# 0     0.442633  0.124150     0.006983     0.013083  ...        282.0
# 1     0.444067  0.124000     0.006983     0.013117  ...        282.0
# 2     0.446067  0.123533     0.006983     0.013083  ...        282.0
# 3     0.446583  0.123133     0.006983     0.013000  ...        282.0
# 4     0.446533  0.122850     0.006850     0.012783  ...        282.0
#
#    precipIntensity  dewPoint  precipProbability  month  day  weekday  \
# 0              0.0      24.4                0.0      1    1      0.0
# 1              0.0      24.4                0.0      1    1      0.0
# 2              0.0      24.4                0.0      1    1      0.0
# 3              0.0      24.4                0.0      1    1      0.0
# 4              0.0      24.4                0.0      1    1      0.0
#
#    weekofyear  hour  minute
# 0          53     5       0
# 1          53     5       1
# 2          53     5       2
# 3          53     5       3
# 4          53     5       4
#
# [5 rows x 36 columns]

# %%
# Resample data to hourly
resampled_df = df.set_index('time')
resampled_df = resampled_df.resample('H').mean()
resampled_df.shape
# Out:
# (8399, 35)

# %%
# Create 80,10,10 train test validation split
target = 'use'

# Split data
train = resampled_df[0:int(len(resampled_df)*0.8)]
valid = resampled_df[int(len(resampled_df)*0.8):int(len(resampled_df)*0.9)]
test = resampled_df[int(len(resampled_df)*0.9):]

# Create X and Y
X_train, Y_train = train.drop([target], axis=1), train[target]
X_valid, Y_valid = valid.drop([target], axis=1), valid[target]
X_test, Y_test = test.drop([target], axis=1), test[target]

# %%
# Create an evaulator function
def evaluator(y_pred, y_valid, y_test, pred_frame, plot, save) :
    
    print('MAE:', mean_absolute_error(y_test[:pred_frame], y_pred[:pred_frame]))
    print('MSE:', mean_squared_error(y_test[:pred_frame], y_pred[:pred_frame]))
    
    if plot:
        fig, ax = plt.subplots(figsize=(8, 4)) 
        plt.plot(pd.concat([y_valid[-pred_frame*2:], y_test[0:pred_frame]]).index, pd.concat([y_valid[-pred_frame*2:], y_test[0:pred_frame]]).values, label='Actual Usage')
        plt.plot(y_pred[0:pred_frame].index, y_pred[0:pred_frame].values, label='Forecast Usage')
        y_labels = ax.get_yticks()
        ax.yaxis.set_major_formatter(FormatStrFormatter('%.2fkw'))
        ax.legend(['Actual', 'Forecast'])
        plt.xlabel('Date')
        plt.ylabel("Eletrical Usage")
        plt.title(str(pred_frame) + "-day forecast energy usage using LightGBM")
        plt.gcf().autofmt_xdate()
        if save:
            plt.savefig('../Figures/'+str(pred_frame)+'-day.png')

# %%
# Load training and validation data
lgb_train = lgb.Dataset(X_train, Y_train)
lgb_valid = lgb.Dataset(X_valid, Y_valid)

# %%
# Model 1: Gradient Descent LGBM Model
lgbm_gd = lgb.train({
        'task' : 'train',
        'objective' : 'regression',
        'boosting':'gbdt',
        'learning_rate':0.05,
        'metric' : {'mse'},
        'num_leaves':200,
        'seed':42,
    }, 
    train_set = lgb_train,
    num_boost_round = 10000,
    valid_sets = [lgb_train, lgb_valid],
    early_stopping_rounds=15)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001132 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7076
# [LightGBM] [Info] Number of data points in the train set: 6719, number of used features: 33
# [LightGBM] [Info] Start training from score 0.874435
# [1]	training's l2: 0.688525	valid_1's l2: 0.22302
# Training until validation scores don't improve for 15 rounds
# [2]	training's l2: 0.629002	valid_1's l2: 0.211203
# [3]	training's l2: 0.575157	valid_1's l2: 0.202156
# [4]	training's l2: 0.526503	valid_1's l2: 0.195982
# [5]	training's l2: 0.482044	valid_1's l2: 0.191347
# [6]	training's l2: 0.442549	valid_1's l2: 0.187319
# [7]	training's l2: 0.406477	valid_1's l2: 0.184982
# [8]	training's l2: 0.373053	valid_1's l2: 0.185999
# [9]	training's l2: 0.342676	valid_1's l2: 0.188273
# [10]	training's l2: 0.315742	valid_1's l2: 0.19029
# [11]	training's l2: 0.291376	valid_1's l2: 0.192212
# [12]	training's l2: 0.26855	valid_1's l2: 0.197216
# [13]	training's l2: 0.248252	valid_1's l2: 0.201256
# [14]	training's l2: 0.229354	valid_1's l2: 0.206345
# [15]	training's l2: 0.212121	valid_1's l2: 0.210879
# [16]	training's l2: 0.195912	valid_1's l2: 0.21349
# [17]	training's l2: 0.181576	valid_1's l2: 0.217827
# [18]	training's l2: 0.168204	valid_1's l2: 0.220771
# [19]	training's l2: 0.155653	valid_1's l2: 0.221253
# [20]	training's l2: 0.14437	valid_1's l2: 0.227805
# [21]	training's l2: 0.134196	valid_1's l2: 0.232672
# [22]	training's l2: 0.124827	valid_1's l2: 0.240004
# Early stopping, best iteration is:
# [7]	training's l2: 0.406477	valid_1's l2: 0.184982

# %%
# Model 2: DART LGBM Model
lgbm_dart = lgb.train(
      params = {
        'task' : 'train',
        'objective' : 'regression',
        'boosting':'dart',
        'learning_rate':0.01,
        'metric' : {'mse'},
      },
      train_set = lgb_train,
      num_boost_round = 150,
      valid_sets = [lgb_train, lgb_valid],
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001308 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7076
# [LightGBM] [Info] Number of data points in the train set: 6719, number of used features: 33
# [LightGBM] [Info] Start training from score 0.874435
# [1]	training's l2: 0.741663	valid_1's l2: 0.235339
# [2]	training's l2: 0.72918	valid_1's l2: 0.232621
# [3]	training's l2: 0.71696	valid_1's l2: 0.230011
# [4]	training's l2: 0.704968	valid_1's l2: 0.227539
# [5]	training's l2: 0.693229	valid_1's l2: 0.2252
# [6]	training's l2: 0.681736	valid_1's l2: 0.222891
# [7]	training's l2: 0.670494	valid_1's l2: 0.22047
# [8]	training's l2: 0.674437	valid_1's l2: 0.221212
# [9]	training's l2: 0.663352	valid_1's l2: 0.218917
# [10]	training's l2: 0.652535	valid_1's l2: 0.216819
# [11]	training's l2: 0.641818	valid_1's l2: 0.214922
# [12]	training's l2: 0.645514	valid_1's l2: 0.215567
# [13]	training's l2: 0.634916	valid_1's l2: 0.213662
# [14]	training's l2: 0.624642	valid_1's l2: 0.211859
# [15]	training's l2: 0.614478	valid_1's l2: 0.210312
# [16]	training's l2: 0.60448	valid_1's l2: 0.208684
# [17]	training's l2: 0.594789	valid_1's l2: 0.207227
# [18]	training's l2: 0.585325	valid_1's l2: 0.205923
# [19]	training's l2: 0.575909	valid_1's l2: 0.20473
# [20]	training's l2: 0.56679	valid_1's l2: 0.203618
# [21]	training's l2: 0.569028	valid_1's l2: 0.203858
# [22]	training's l2: 0.559903	valid_1's l2: 0.202728
# [23]	training's l2: 0.551217	valid_1's l2: 0.201399
# [24]	training's l2: 0.542637	valid_1's l2: 0.200373
# [25]	training's l2: 0.53416	valid_1's l2: 0.199355
# [26]	training's l2: 0.525862	valid_1's l2: 0.198663
# [27]	training's l2: 0.517755	valid_1's l2: 0.19783
# [28]	training's l2: 0.520786	valid_1's l2: 0.198069
# [29]	training's l2: 0.512701	valid_1's l2: 0.197225
# [30]	training's l2: 0.504825	valid_1's l2: 0.196688
# [31]	training's l2: 0.50527	valid_1's l2: 0.196735
# [32]	training's l2: 0.497197	valid_1's l2: 0.196259
# [33]	training's l2: 0.489625	valid_1's l2: 0.195598
# [34]	training's l2: 0.481876	valid_1's l2: 0.195237
# [35]	training's l2: 0.485688	valid_1's l2: 0.195433
# [36]	training's l2: 0.491156	valid_1's l2: 0.195824
# [37]	training's l2: 0.483631	valid_1's l2: 0.1953
# [38]	training's l2: 0.476312	valid_1's l2: 0.194773
# [39]	training's l2: 0.469171	valid_1's l2: 0.194377
# [40]	training's l2: 0.466991	valid_1's l2: 0.194268
# [41]	training's l2: 0.471135	valid_1's l2: 0.194429
# [42]	training's l2: 0.463745	valid_1's l2: 0.194163
# [43]	training's l2: 0.467616	valid_1's l2: 0.194341
# [44]	training's l2: 0.460509	valid_1's l2: 0.19397
# [45]	training's l2: 0.453585	valid_1's l2: 0.193943
# [46]	training's l2: 0.471035	valid_1's l2: 0.165893
# [47]	training's l2: 0.463934	valid_1's l2: 0.165739
# [48]	training's l2: 0.462957	valid_1's l2: 0.165684
# [49]	training's l2: 0.467286	valid_1's l2: 0.165863
# [50]	training's l2: 0.47185	valid_1's l2: 0.166041
# [51]	training's l2: 0.464687	valid_1's l2: 0.165947
# [52]	training's l2: 0.457396	valid_1's l2: 0.165776
# [53]	training's l2: 0.460668	valid_1's l2: 0.165893
# [54]	training's l2: 0.453792	valid_1's l2: 0.165749
# [55]	training's l2: 0.446699	valid_1's l2: 0.16574
# [56]	training's l2: 0.451596	valid_1's l2: 0.165827
# [57]	training's l2: 0.444759	valid_1's l2: 0.165872
# [58]	training's l2: 0.482874	valid_1's l2: 0.15907
# [59]	training's l2: 0.487168	valid_1's l2: 0.159125
# [60]	training's l2: 0.479438	valid_1's l2: 0.15879
# [61]	training's l2: 0.529674	valid_1's l2: 0.171011
# [62]	training's l2: 0.521366	valid_1's l2: 0.170305
# [63]	training's l2: 0.512918	valid_1's l2: 0.169132
# [64]	training's l2: 0.516104	valid_1's l2: 0.169124
# [65]	training's l2: 0.519908	valid_1's l2: 0.169272
# [66]	training's l2: 0.511743	valid_1's l2: 0.168786
# [67]	training's l2: 0.503494	valid_1's l2: 0.167729
# [68]	training's l2: 0.495674	valid_1's l2: 0.16697
# [69]	training's l2: 0.49944	valid_1's l2: 0.167058
# [70]	training's l2: 0.501366	valid_1's l2: 0.16705
# [71]	training's l2: 0.50355	valid_1's l2: 0.166938
# [72]	training's l2: 0.495636	valid_1's l2: 0.166442
# [73]	training's l2: 0.487896	valid_1's l2: 0.165792
# [74]	training's l2: 0.491039	valid_1's l2: 0.16587
# [75]	training's l2: 0.483123	valid_1's l2: 0.165246
# [76]	training's l2: 0.483617	valid_1's l2: 0.165241
# [77]	training's l2: 0.486207	valid_1's l2: 0.16526
# [78]	training's l2: 0.488818	valid_1's l2: 0.165259
# [79]	training's l2: 0.481174	valid_1's l2: 0.164869
# [80]	training's l2: 0.473791	valid_1's l2: 0.164345
# [81]	training's l2: 0.476919	valid_1's l2: 0.164312
# [82]	training's l2: 0.469269	valid_1's l2: 0.16374
# [83]	training's l2: 0.47293	valid_1's l2: 0.16376
# [84]	training's l2: 0.476581	valid_1's l2: 0.163749
# [85]	training's l2: 0.48022	valid_1's l2: 0.163797
# [86]	training's l2: 0.472768	valid_1's l2: 0.163506
# [87]	training's l2: 0.46535	valid_1's l2: 0.163124
# [88]	training's l2: 0.469658	valid_1's l2: 0.163126
# [89]	training's l2: 0.471919	valid_1's l2: 0.163025
# [90]	training's l2: 0.47567	valid_1's l2: 0.163032
# [91]	training's l2: 0.526993	valid_1's l2: 0.180938
# [92]	training's l2: 0.518632	valid_1's l2: 0.180013
# [93]	training's l2: 0.510148	valid_1's l2: 0.178777
# [94]	training's l2: 0.51419	valid_1's l2: 0.179181
# [95]	training's l2: 0.516938	valid_1's l2: 0.179242
# [96]	training's l2: 0.52	valid_1's l2: 0.179386
# [97]	training's l2: 0.51166	valid_1's l2: 0.178624
# [98]	training's l2: 0.514381	valid_1's l2: 0.178538
# [99]	training's l2: 0.506299	valid_1's l2: 0.177731
# [100]	training's l2: 0.49805	valid_1's l2: 0.176692
# [101]	training's l2: 0.525755	valid_1's l2: 0.187329
# [102]	training's l2: 0.529254	valid_1's l2: 0.187621
# [103]	training's l2: 0.532903	valid_1's l2: 0.18789
# [104]	training's l2: 0.524469	valid_1's l2: 0.186772
# [105]	training's l2: 0.551615	valid_1's l2: 0.198497
# [106]	training's l2: 0.555158	valid_1's l2: 0.198663
# [107]	training's l2: 0.558931	valid_1's l2: 0.19897
# [108]	training's l2: 0.549886	valid_1's l2: 0.197594
# [109]	training's l2: 0.552783	valid_1's l2: 0.197749
# [110]	training's l2: 0.555989	valid_1's l2: 0.197828
# [111]	training's l2: 0.547073	valid_1's l2: 0.196362
# [112]	training's l2: 0.538074	valid_1's l2: 0.19451
# [113]	training's l2: 0.52947	valid_1's l2: 0.193012
# [114]	training's l2: 0.520973	valid_1's l2: 0.191686
# [115]	training's l2: 0.512452	valid_1's l2: 0.190165
# [116]	training's l2: 0.504364	valid_1's l2: 0.188879
# [117]	training's l2: 0.507143	valid_1's l2: 0.189053
# [118]	training's l2: 0.498892	valid_1's l2: 0.187698
# [119]	training's l2: 0.501871	valid_1's l2: 0.18777
# [120]	training's l2: 0.505436	valid_1's l2: 0.187901
# [121]	training's l2: 0.509003	valid_1's l2: 0.188112
# [122]	training's l2: 0.512631	valid_1's l2: 0.188307
# [123]	training's l2: 0.504448	valid_1's l2: 0.187363
# [124]	training's l2: 0.496484	valid_1's l2: 0.186143
# [125]	training's l2: 0.499238	valid_1's l2: 0.186164
# [126]	training's l2: 0.502526	valid_1's l2: 0.186272
# [127]	training's l2: 0.494457	valid_1's l2: 0.185213
# [128]	training's l2: 0.497614	valid_1's l2: 0.185419
# [129]	training's l2: 0.489497	valid_1's l2: 0.184364
# [130]	training's l2: 0.481823	valid_1's l2: 0.183703
# [131]	training's l2: 0.485038	valid_1's l2: 0.183953
# [132]	training's l2: 0.477451	valid_1's l2: 0.183025
# [133]	training's l2: 0.469747	valid_1's l2: 0.182088
# [134]	training's l2: 0.492908	valid_1's l2: 0.19117
# [135]	training's l2: 0.484869	valid_1's l2: 0.19022
# [136]	training's l2: 0.515974	valid_1's l2: 0.2038
# [137]	training's l2: 0.51935	valid_1's l2: 0.204022
# [138]	training's l2: 0.511054	valid_1's l2: 0.202872
# [139]	training's l2: 0.502906	valid_1's l2: 0.201593
# [140]	training's l2: 0.507088	valid_1's l2: 0.20191
# [141]	training's l2: 0.510297	valid_1's l2: 0.202056
# [142]	training's l2: 0.513763	valid_1's l2: 0.202286
# [143]	training's l2: 0.505377	valid_1's l2: 0.200898
# [144]	training's l2: 0.508236	valid_1's l2: 0.201011
# [145]	training's l2: 0.499917	valid_1's l2: 0.199546
# [146]	training's l2: 0.504134	valid_1's l2: 0.199866
# [147]	training's l2: 0.50828	valid_1's l2: 0.20032
# [148]	training's l2: 0.511901	valid_1's l2: 0.200562
# [149]	training's l2: 0.503751	valid_1's l2: 0.199402
# [150]	training's l2: 0.495479	valid_1's l2: 0.198212

# %%
def predict(model, x_test) :
    out_df = pd.DataFrame()
    out_df[target] = model.predict(x_test, num_iteration=model.best_iteration)
    out_df.index = x_test.index
    return out_df

# %%
# Predict
dart_pred = predict(lgbm_dart, X_test)
gd_pred = predict(lgbm_gd, X_test)

# %%
# Plot multi-period forecasts
for period in [24,48,7*24,14*24,30*24] :
# for period in [7,14,30,60,120,360] :
    evaluator(gd_pred['use'], Y_valid, Y_test, period, plot=True, save=True)
# Out:
# MAE: 0.22124956709533766
# MSE: 0.053607039155990306
# MAE: 0.22933517451214644
# MSE: 0.07416776361011887
# MAE: 0.27217537144884907
# MSE: 0.12297111292376803
# MAE: 0.2952161526969118
# MSE: 0.1334091941569242
# MAE: 0.29290358779241815
# MSE: 0.14586824803138299
# MAE: 0.3524980432348351
# MSE: 0.22559710272005445
